# %% [markdown]
# # World Happiness ReportProject

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# The dataset contain This dataset contains details of customers in which both numerical and categorical data is present. In this dataset 'Happiness Score' is our target variable as all the other independent columns helps in determining
# the happiness score of a country.

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# The dataset contains 158 rows and 12 columns

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# The dataset contains three types of datatypes(int64,object,float64)

# %%
#checking null values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No null values present.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# # Summary of data

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# 1) mean is almost equal to median in all columns.
# 2) There is a very less difference between 75th percentile and max value which indicates no outliers are there.

# %%
#columns (country,region,happiness rank) do not impact much on target variable so we're dropping them.
df.drop(['Country','Region','Happiness Rank'],axis=1,inplace=True)
df.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Score                158 non-null    float64
#  1   Standard Error                 158 non-null    float64
#  2   Economy (GDP per Capita)       158 non-null    float64
#  3   Family                         158 non-null    float64
#  4   Health (Life Expectancy)       158 non-null    float64
#  5   Freedom                        158 non-null    float64
#  6   Trust (Government Corruption)  158 non-null    float64
#  7   Generosity                     158 non-null    float64
#  8   Dystopia Residual              158 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %% [markdown]
# # Data Visualisation

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Standard Error densely lies between 0.03 to 0.05

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Happiness score is increasing as per increase in per capita GDP. Also economy is densely populated between 0.25 to 1.40

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Happiness score is increasing as per increase in family score. Also family score is dense between 0.60 to 1.40

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Happiness score is increasing as per increase in Health means good health contrbutes to happiness score. Heath is dense between
# 0.6 to 1.0

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Happiness score is increasing as per increase in freedom

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Trust is dense in range 0.0 to 0.20

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Happiness score is increasing as per increase in generosity and is more between 0.1 to 0.5

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)
plt.show()

# %% [markdown]
# Dystopia residual is dense where the happiness score is between 0.4 to 0.7

# %% [markdown]
# # Checking for outliers

# %%
df.plot(kind='box',subplots=True,layout=(3,3))
plt.show()

# %% [markdown]
# outliers are present in Standard error, family, trust, dystopia residual

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

# %%
dfs=df.copy()

# %%
z=np.abs(zscore(df))
z
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 0           1.937360        0.805926                  1.369621  1.320281
# 1           1.914581        0.055889                  1.135226  1.514458
# 2           1.884792        0.854487                  1.192861  1.361054
# 3           1.880411        0.531526                  1.525130  1.251922
# 4           1.797179        0.722845                  1.194876  1.221204
# ..               ...             ...                       ...       ...
# 153         1.674055        0.774917                  1.552987  0.800520
# 154         1.783571        0.662582                  1.392303  2.346860
# 155         2.076199        0.132534                  0.455245  1.901086
# 156         2.164688        2.263962                  2.067566  2.118467
# 157         2.222513        1.134182                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
z.iloc[27,6]
# Out:
# 3.1646194851713774

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (149, 9)

# %%
df.shape
# Out:
# (158, 9)

# %%
print('Data loss in percentage:',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss in percentage: 5.69620253164557

# %% [markdown]
# # Checking skewness

# %%
plt.figure(figsize=(35,30), facecolor='white')
plotnumber=1
for col in df1:
    if plotnumber<=9:
        ax=plt.subplot(5,6,plotnumber)
        sns.distplot(df[col], color='m')
        plt.xlabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %%
df1.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# Skewness is present in (Standard Error,Trust,Generosity) is right skewed and in(family,health) is left skewed

# %%
from scipy.stats import boxcox

# %%
columns=['Standard Error','Trust (Government Corruption)','Generosity']

# %%
for col in columns:
    df1[col], _=boxcox(df1[col] + 1)

# %%
df1.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.002527
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    0.174593
# Generosity                       0.025172
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# Data skewed

# %% [markdown]
# # Checking correlation

# %%
df1.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.239650
# Standard Error                       -0.239650        1.000000
# Economy (GDP per Capita)              0.773577       -0.235225
# Family                                0.685889       -0.075272
# Health (Life Expectancy)              0.729191       -0.326990
# Freedom                               0.585066       -0.211237
# Trust (Government Corruption)         0.404730       -0.109173
# Generosity                            0.231255       -0.136514
# Dystopia Residual                     0.528334        0.013038
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.773577  0.685889
# Standard Error                                -0.235225 -0.075272
# Economy (GDP per Capita)                       1.000000  0.605242
# Family                                         0.605242  1.000000
# ...

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Seperating the data

# %%
x=df1.drop('Happiness Score',axis=1)
y=df1['Happiness Score']

# %% [markdown]
# # Scaling using standard scaler method

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0         -0.950831                  1.381916  1.173892
# 1          0.374966                  1.138324  1.324528
# 2         -1.041137                  1.198220  1.205844
# 3         -0.474458                  1.543526  1.119928
# 4         -0.800632                  1.200315  1.095516
# ..              ...                       ...       ...
# 144        0.560156                 -1.026255 -0.820054
# 145       -0.072340                 -1.562163 -0.491949
# 146       -1.317782                 -1.402596 -3.422844
# 147       -0.694988                 -1.488379 -3.043626
# 148        2.194884                 -2.190139 -2.628905
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.235390  1.583704                       1.817625
# 1                    1.261541  1.338953                       0.329676
# 2                    0.962900  1.476027                       1.953400
# ...

# %% [markdown]
# # To handle multicollinearity we use Variance inflation factor (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns
vif
# Out:
#    VIF values                       features
# 0    1.157621                 Standard Error
# 1    4.067059       Economy (GDP per Capita)
# 2    1.805201                         Family
# 3    3.381511       Health (Life Expectancy)
# 4    1.916607                        Freedom
# 5    1.396571  Trust (Government Corruption)
# 6    1.339108                     Generosity
# 7    1.029287              Dystopia Residual

# %% [markdown]
# VIF is in range of 5 so no need to drop any column

# %% [markdown]
# # Model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,accuracy_score,confusion_matrix,mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso,Ridge

# %%
maxAccu=0
maxRS=0
for i in range(1,210):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=i)
    LR= LinearRegression()
    LR.fit(x_train,y_train)
    pred=LR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum r2_score is:',maxAccu, 'at random state:',maxRS)
# Out:
# Maximum r2_score is: 0.9986273155347258 at random state: 72

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=72)

# %% [markdown]
# # Again predicting Linear Regression with best random state

# %%
LR= LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('LR')
print('r2 score:',r2_score(y_test, pred_LR))
print('r2 score on training data:',r2_score(y_train, pred_train))
print('mean absolute error :',mean_absolute_error(y_test, pred_LR))
print('mean squared error :',mean_squared_error(y_test, pred_LR))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test, pred_LR)))
print('\n')
# Out:
# LR
# r2 score: 0.9986273155347258
# r2 score on training data: 0.9974071220077093
# mean absolute error : 0.036568011786755956
# mean squared error : 0.0022328278677662973
# root mean squared error : 0.047252808041070925

# %%
model=[RandomForestRegressor(),
        DecisionTreeRegressor(),
        AdaBoostRegressor(),
        GradientBoostingRegressor(),
        Lasso(),
        Ridge()]

# %%
for m in model:
    m.fit(x_train,y_train)
    pred_m=m.predict(x_test)
    pred_train=m.predict(x_train)
    print('Model prediction for :',m)
    print('r2 score:',r2_score(y_test, pred_m))
    print('r2 score on training data:',r2_score(y_train, pred_train))
    print('mean absolute error :',mean_absolute_error(y_test, pred_m))
    print('mean squared error :',mean_squared_error(y_test, pred_m))
    print('root mean squared error :',np.sqrt(mean_squared_error(y_test, pred_m)))
    print('\n')
# Out:
# Model prediction for : RandomForestRegressor()
# r2 score: 0.9288964196257671
# r2 score on training data: 0.9842506432048623
# mean absolute error : 0.25927022222222174
# mean squared error : 0.1156580844133329
# root mean squared error : 0.34008540752777516
#
#
# Model prediction for : DecisionTreeRegressor()
# r2 score: 0.8196893886456127
# r2 score on training data: 1.0
# mean absolute error : 0.4027555555555557
# mean squared error : 0.29329577777777777
# root mean squared error : 0.5415678884293065
#
#
# Model prediction for : AdaBoostRegressor()
# r2 score: 0.8908034886422026
# r2 score on training data: 0.9518974490930338
# mean absolute error : 0.33540322442244036
# mean squared error : 0.17762058199868588
# root mean squared error : 0.42145056886743654
#
#
# Model prediction for : GradientBoostingRegressor()
# r2 score: 0.9537911743782796
# r2 score on training data: 0.9991742137879579
# mean absolute error : 0.20678030528386304
# mean squared error : 0.07516392601144828
# ...

# %% [markdown]
# # Cross validation to check actual performance of these above models

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('Cross validation score for :',m)
    print('Model score :',score)
    print('mean score :',score.mean())
    print('difference between r2 score and Cross validation score :',r2_score(y_test, pred_m)-score.mean())
    print('\n')
# Out:
# Cross validation score for : RandomForestRegressor()
# Model score : [-7.95395595 -1.14480369 -0.61362818 -2.0484398  -6.67599564]
# mean score : -3.6873646524569397
# difference between r2 score and Cross validation score : 4.685969250604723
#
#
# Cross validation score for : DecisionTreeRegressor()
# Model score : [ -6.1333322   -6.98001962  -5.92355549 -10.88868987  -5.93051609]
# mean score : -7.1712226545025475
# difference between r2 score and Cross validation score : 8.16982725265033
#
#
# Cross validation score for : AdaBoostRegressor()
# Model score : [-10.00734365  -5.22564418  -2.29048958  -6.0389722   -7.84061508]
# mean score : -6.280612938127779
# difference between r2 score and Cross validation score : 7.279217536275562
#
#
# Cross validation score for : GradientBoostingRegressor()
# Model score : [-4.35818482  0.02442311 -0.51746831 -3.8486087  -3.98575959]
# mean score : -2.537119659262841
# difference between r2 score and Cross validation score : 3.5357242574106245
# ...

# %% [markdown]
# Ridge is our best model as the difference between r2 score and Cross validation score least and highest accuracy score

# %% [markdown]
# # Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'alpha':[0.5,0.7,1.0],'fit_intercept':[True,False],
            'solver':['auto','svd','lsqr','sag']}
gcvs=GridSearchCV(Ridge(),parameters,cv=5)
gcvs.fit(x_train,y_train)
gcvs.best_params_
# Out:
# {'alpha': 0.7, 'fit_intercept': True, 'solver': 'sag'}

# %% [markdown]
# # Final Model

# %%
model_test=Ridge(alpha=0.7,fit_intercept=True,solver='sag')
model_test.fit(x_train,y_train)
pred_g=model_test.predict(x_test)
print('r2 score:',r2_score(y_test, pred_g))
print('mean absolute error :',mean_absolute_error(y_test, pred_g))
print('mean squared error :',mean_squared_error(y_test, pred_g))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test, pred_g)))
# Out:
# r2 score: 0.9986192039122092
# mean absolute error : 0.03714799166762993
# mean squared error : 0.0022460223470995404
# root mean squared error : 0.047392218212482316

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(model_test,'World_Happiness_Report.pkl')
# Out:
# ['World_Happiness_Report.pkl']

# %% [markdown]
# # Predicting the same model for future use

# %%
mod=joblib.load('World_Happiness_Report.pkl')
prediction=mod.predict(x_test)

# %%
a=np.array(y_test)
df_new=pd.DataFrame()
df_new['predicted']=prediction
df_new['original']=a
df_new
# Out:
#     predicted  original
# 0    6.870207     6.867
# 1    5.034579     5.013
# 2    4.183488     4.292
# 3    4.562709     4.514
# 4    3.778677     3.781
# 5    5.252604     5.192
# 6    5.032091     5.007
# 7    3.656527     3.656
# 8    7.385299     7.427
# 9    7.254078     7.226
# 10   6.346161     6.329
# 11   7.534788     7.561
# 12   5.065611     5.102
# 13   7.169012     7.119
# 14   6.514168     6.485
# 15   4.944478     4.971
# 16   2.789691     2.905
# 17   6.558967     6.574
# 18   6.854141     6.750
# 19   6.409474     6.411
# 20   5.129875     5.073
# 21   4.421253     4.419
# 22   6.813271     6.786
# 23   5.452179     5.360
# 24   5.172794     5.140
# 25   3.927499     3.896
# 26   7.226578     7.284
# 27   4.002701     3.995
# 28   3.260908     3.340
# 29   7.368357     7.378
# 30   5.850846     5.824
# 31   3.989070     3.956
# 32   4.560747     4.512
# 33   4.168918     4.218
# 34   6.947679     6.946
# 35   6.740646     6.810
# 36   6.025313     5.987
# ...
