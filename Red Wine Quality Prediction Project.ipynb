# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# This dataset contains details of wine which has only numerical data. The dataset has 1599 rows and 12 columns in which 'Quality'
# is our target variable and is continuous in nature therefore we'll using Regression method in this dataset

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# The dataset contains only two data type (float64 and int 64)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# No null values are present in the dataset

# %%
# Visualisation of null values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %% [markdown]
# No blank space present in any colunms

# %% [markdown]
# # Summary of data

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# from the above description we can conclude that:
# 1) mean>median in almost all columns but slightly so we can say data is little skewed towards right.
# 2) we can see large gap between 75th percentile and max value in 'fixed acidity','residual sugar','free sulphur dioxide','total sulphur dioxide'
#    which indicates presence of outliers.

# %% [markdown]
# # Creating binary values for our dependent variable(Quality)

# %% [markdown]
# We'll create 2 classes for classifying our wine quality grade
#
# class 1= Good quality wine (if grade is 7 or higher )
#
# class 2= Not good quality wine (if grade is less than 7)

# %%
df['class']=df['quality'].apply(lambda x:1 if x>=7 else 0)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#dropping the quality column as required
df1=df.drop(columns='quality')
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1['class'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: class, dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
sns.catplot(x='quality',kind='count',data=df)
plt.show()

# %% [markdown]
# We can see a large number of wines are of quality 5 and 6 in this dataset.

# %%
plt.figure(figsize=(35,30), facecolor='white')
plotnumber=1
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(5,6,plotnumber)
        sns.distplot(df[col], color='m')
        plt.xlabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# From the above graph we can see that free sulphur dioxide, total sulphur dioxide and alcohal are skewed towards right
# and remaining columns are normally distributed

# %%
plt.figure(figsize=(15,18), facecolor='white')
plotnumber=1
for col in df1:
    if plotnumber<=12:
        ax=plt.subplot(5,6,plotnumber)
        sns.barplot(x='class',y=col,data=df1)
        plt.xlabel('class',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# In the above graph we can see that quality of wine increases with increase in fixed acidity,citric acidity,sulphates and alcohal.
# and decreases with increase in volatile acidity,chloride,free sulphur dioxide and total sulphur dioxide.

# %% [markdown]
# # Checking for outliers

# %%
plt.figure(figsize=(17,21), facecolor='white')
plotnumber=1
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(5,6,plotnumber)
        sns.boxplot(x='quality',y=col,data=df)
        plt.xlabel('quality',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# We can see presence of outliers

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

# %%
dfs=df1.copy()

# %%
z=np.abs(zscore(df1))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         467,  480,  480,  494,  515,  544,  554,  554,  555,  555,  557,
#         557,  568,  584,  588,  591,  595,  608,  614,  636,  639,  649,
#         649,  651,  652,  652,  652,  672,  672,  684,  690,  692,  692,
#         695,  723,  724,  730,  754,  776,  777,  795,  821,  836,  837,
#         889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043, 1051,
#        1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154,
#        1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269,
# ...

# %%
z.iloc[14,5], z.iloc[15,5]
# Out:
# (3.454668962073944, 3.359038194288537)

# %%
df2=df1[(z<3).all(axis=1)]
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print('Old Data',df1.shape)
print('New data',df2.shape)
print('Data loss in percentage:',((df1.shape[0]-df2.shape[0])/df1.shape[0])*100)
# Out:
# Old Data (1599, 12)
# New data (1458, 12)
# Data loss in percentage: 8.818011257035648

# %% [markdown]
# # Checking for skewness

# %%
# replacing df1 with dfs since some error occured while removing skewness
dfs.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# class                   2.129363
# dtype: float64

# %% [markdown]
# The columns are highly skewed.

# %%
#columns thst needs to be skewed
sk=dfs.skew()
sk=sk[abs(sk)>0.5].index
sk
# Out:
# Index(['fixed acidity', 'volatile acidity', 'residual sugar', 'chlorides',
#        'free sulfur dioxide', 'total sulfur dioxide', 'sulphates', 'alcohol',
#        'class'],
#       dtype='object')

# %%
from scipy.stats import boxcox

# %%
for col in sk:
    dfs[col], _=boxcox(dfs[col] + 1)

# %%
dfs.skew()
# Out:
# fixed acidity           0.002529
# volatile acidity        0.003099
# citric acid             0.318337
# residual sugar         -0.015714
# chlorides              -0.151304
# free sulfur dioxide    -0.009948
# total sulfur dioxide   -0.003752
# density                 0.071288
# pH                      0.193683
# sulphates               0.009985
# alcohol                 0.112372
# class                   2.129363
# dtype: float64

# %% [markdown]
# skewness has been removed

# %%
plt.figure(figsize=(35,30), facecolor='white')
plotnumber=1
for col in dfs:
    if plotnumber<=12:
        ax=plt.subplot(5,6,plotnumber)
        sns.distplot(dfs[col], color='m')
        plt.xlabel(col,fontsize=20)
        plt.ylabel('class',fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# # Checking correlation between target and independent variables

# %%
cor=dfs.corr()
cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.257764     0.655130
# volatile acidity          -0.257764          1.000000    -0.569564
# citric acid                0.655130         -0.569564     1.000000
# residual sugar             0.211126          0.048267     0.177922
# chlorides                  0.263545          0.145660     0.149791
# free sulfur dioxide       -0.173330          0.023704    -0.086224
# total sulfur dioxide      -0.109233          0.091369    -0.001687
# density                    0.673500          0.035840     0.364947
# pH                        -0.715664          0.231305    -0.541904
# sulphates                  0.194683         -0.318655     0.333063
# alcohol                   -0.102182         -0.214187     0.099377
# class                      0.103631         -0.289182     0.214716
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
#graphical representation of above correlated values
plt.figure(figsize=(14,17))
sns.heatmap(dfs.corr(),annot=True,linewidth=0.1,fmt='.2g')
plt.show()

# %% [markdown]
# 1) Class is positively corelated with alcohal,sulphate,citric acid.
# 2) Target variable is negatively correlated with volatile acidity,chloride,free and total sulphur dioxide,density,ph.
# 3) Fixed acidity and citric acid, fixed acidity and density, fre sulphur dioxide and total sulphur dioxide are corelated with each other

# %% [markdown]
# # Seperating the data

# %%
x=df2.drop('class',axis=1)
y=df2['class']

# %%
print('Feature dimension', x.shape)
print('Label dimension', y.shape)
# Out:
# Feature dimension (1458, 11)
# Label dimension (1458,)

# %% [markdown]
# # Scaling using standard scaler method

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.554045          1.038708    -1.387413       -0.564985  -0.260755
# 1         -0.311190          2.101325    -1.387413        0.244255   0.776445
# 2         -0.311190          1.392914    -1.178214       -0.102562   0.493572
# 3          1.753082         -1.440732     1.541370       -0.564985  -0.307900
# 4         -0.554045          1.038708    -1.387413       -0.564985  -0.260755
# ...             ...               ...          ...             ...        ...
# 1453      -1.282612          0.448365    -0.969015       -0.449379   0.399281
# 1454      -1.464753          0.153194    -0.864416       -0.218168  -0.920791
# 1455      -1.221898         -0.082944    -0.707517       -0.102562  -0.260755
# 1456      -1.464753          0.714019    -0.759816       -0.449379  -0.307900
# 1457      -1.404040         -1.263630     1.070673        1.400311  -0.685064
#
# ...

# %% [markdown]
# Data has been scaled to overcome the issue of biasness

# %% [markdown]
# # To handle multicollinearity we use Variance inflation factor (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns
vif
# Out:
#     VIF values              features
# 0     7.941157         fixed acidity
# 1     1.869151      volatile acidity
# 2     3.200976           citric acid
# 3     1.657880        residual sugar
# 4     1.170025             chlorides
# 5     1.936150   free sulfur dioxide
# 6     2.182674  total sulfur dioxide
# 7     6.420347               density
# 8     3.199093                    pH
# 9     1.311525             sulphates
# 10    3.233350               alcohol

# %% [markdown]
# In general if VIF>5 then those variables are creating multicollinearity like in above fixed acidity and density but we'll not
# drop fixed acidity column as it is positively increasing the quality of wine and density is neutral to quality of wine

# %%
y.value_counts()
# Out:
# 0    1257
# 1     201
# Name: class, dtype: int64

# %% [markdown]
# As we can see data is not balanced we'll do oversampling to balance it

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x1,y1=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    1257
# 1     201
# Name: class, dtype: int64

# %%
y1.value_counts()
# Out:
# 0    1257
# 1    1257
# Name: class, dtype: int64

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
maxAccu=0
maxRS=0
for i in range(1,220):
    x_train,x_test,y_train,y_test= train_test_split(x1,y1,test_size=.30,random_state=i)
    DTC= DecisionTreeClassifier()
    DTC.fit(x_train,y_train)
    pred=DTC.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum accuracy score is:',maxAccu, 'at random state:',maxRS)
# Out:
# Maximum accuracy score is: 0.9311258278145695 at random state: 1

# %% [markdown]
# # Again predicting decision tree classifier

# %%
x_train,x_test,y_train,y_test= train_test_split(x1,y1,test_size=.30,random_state=maxRS)
DTC= DecisionTreeClassifier()
DTC.fit(x_train,y_train)
predDTC=DTC.predict(x_test)
print('accuracy score',accuracy_score(y_test,predDTC))
print('confusion matrix',confusion_matrix(y_test,predDTC))
print('classification report',classification_report(y_test,predDTC))
# Out:
# accuracy score 0.9245033112582781
# confusion matrix [[338  33]
#  [ 24 360]]
# classification report               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       371
#            1       0.92      0.94      0.93       384
#
#     accuracy                           0.92       755
#    macro avg       0.92      0.92      0.92       755
# weighted avg       0.92      0.92      0.92       755

# %% [markdown]
# # Logistic Regression

# %%
lg= LogisticRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print('accuracy score:',accuracy_score(y_test, predlg))
print('confusion matrix :\n',confusion_matrix(y_test, predlg))
print('classification report :\n',classification_report(y_test, predlg))
# Out:
# accuracy score: 0.847682119205298
# confusion matrix :
#  [[311  60]
#  [ 55 329]]
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       371
#            1       0.85      0.86      0.85       384
#
#     accuracy                           0.85       755
#    macro avg       0.85      0.85      0.85       755
# weighted avg       0.85      0.85      0.85       755

# %%
models=[GaussianNB(),
        KNeighborsClassifier(),
        SVC(),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

# %%
for m in models:
    m.fit(x_train,y_train)
    pred_m=m.predict(x_test)
    print('Model prediction for :',m)
    print('accuracy score:',accuracy_score(y_test, pred_m))
    print('confusion matrix :\n',confusion_matrix(y_test, pred_m))
    print('classification report :\n',classification_report(y_test, pred_m))
    print('\n')
# Out:
# Model prediction for : GaussianNB()
# accuracy score: 0.8264900662251655
# confusion matrix :
#  [[304  67]
#  [ 64 320]]
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       371
#            1       0.83      0.83      0.83       384
#
#     accuracy                           0.83       755
#    macro avg       0.83      0.83      0.83       755
# weighted avg       0.83      0.83      0.83       755
#
#
#
# Model prediction for : KNeighborsClassifier()
# accuracy score: 0.8927152317880794
# confusion matrix :
#  [[291  80]
#  [  1 383]]
# classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88       371
#            1       0.83      1.00      0.90       384
#
#     accuracy                           0.89       755
#    macro avg       0.91      0.89      0.89       755
# weighted avg       0.91      0.89      0.89       755
#
# ...

# %% [markdown]
# As we can see RandomForestClassifier is giving maximum accuracy of 0.96158 among all.

# %% [markdown]
# # Cross validation to check actual performance of these above models

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in models:
    score=cross_val_score(m,x1,y1)
    print('Cross validation score for :',m)
    print('Model score :',score)
    print('mean score :',score.mean())
    print('difference between accuracy score and Cross validation score :',accuracy_score(y_test, pred_m)-score.mean())
    print('\n')
# Out:
# Cross validation score for : GaussianNB()
# Model score : [0.85685885 0.67992048 0.83697813 0.71371769 0.80278884]
# mean score : 0.7780527987453763
# difference between accuracy score and Cross validation score : 0.16631806218177603
#
#
# Cross validation score for : KNeighborsClassifier()
# Model score : [0.92246521 0.80914513 0.86878728 0.78926441 0.83067729]
# mean score : 0.8440678637339311
# difference between accuracy score and Cross validation score : 0.10030299719322122
#
#
# Cross validation score for : SVC()
# Model score : [0.92246521 0.84095427 0.90059642 0.79522863 0.87450199]
# mean score : 0.8667493049670106
# difference between accuracy score and Cross validation score : 0.07762155596014164
#
#
# Cross validation score for : RandomForestClassifier()
# Model score : [0.96023857 0.88071571 0.93836978 0.87475149 0.92430279]
# mean score : 0.9156756671128606
# difference between accuracy score and Cross validation score : 0.028695193814291642
#
#
# ...

# %% [markdown]
# RandomForestClassifier is best model since the difference between accuracy score and Cross validation score is lowest among all

# %% [markdown]
# # Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['gini','entropy','log_loss'],'n_estimators':[10,30,50,100],'max_depth':[10,30,50,80],'max_features':['auto','sqrt'],'n_jobs':[-2,-1,1]}
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 30,
#  'max_features': 'sqrt',
#  'n_estimators': 100,
#  'n_jobs': -1}

# %% [markdown]
# # Final Model

# %%
final=RandomForestClassifier(criterion='gini',max_depth=30,max_features='sqrt',n_estimators=100,n_jobs=-1)
final.fit(x_train,y_train)
pred_f=final.predict(x_test)
accu=accuracy_score(y_test,pred_f)

# %%
print(accu*100)
# Out:
# 96.68874172185431

# %% [markdown]
# # AUC ROC curve

# %%
from sklearn import metrics

# %%
fpr,tpr,thresholds=metrics.roc_curve(y_test,pred_f)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=final)
display.plot()

# %% [markdown]
# The AUC value for RandomForestClassifier is 0.97

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(final,'Red_wine_prediction.pkl')
# Out:
# ['Red_wine_prediction.pkl']

# %% [markdown]
# # Final Prediction

# %%
prediction=final.predict(x_test)
original=np.array(y_test)
df_final=pd.DataFrame()
df_final['Predicted']= prediction
df_final['Original value']= original
df_final
# Out:
#      Predicted  Original value
# 0            0               0
# 1            1               1
# 2            0               0
# 3            1               1
# 4            1               1
# ..         ...             ...
# 750          0               0
# 751          0               0
# 752          1               1
# 753          1               0
# 754          1               1
#
# [755 rows x 2 columns]
