# %% [markdown]
# # Glass Identification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv')
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
column_names=['Id number','Refractive index','Sodium','Magnisium','Aluminium','Silicon','Potassium','Calcium','Barium','Iron','Type of glass']

# %%
df.columns=column_names

# %%
df
# Out:
#      Id number  Refractive index  Sodium  Magnisium  Aluminium  Silicon  \
# 0            2           1.51761   13.89       3.60       1.36    72.73
# 1            3           1.51618   13.53       3.55       1.54    72.99
# 2            4           1.51766   13.21       3.69       1.29    72.61
# 3            5           1.51742   13.27       3.62       1.24    73.08
# 4            6           1.51596   12.79       3.61       1.62    72.97
# ..         ...               ...     ...        ...        ...      ...
# 208        210           1.51623   14.14       0.00       2.88    72.61
# 209        211           1.51685   14.92       0.00       1.99    73.06
# 210        212           1.52065   14.36       0.00       2.02    73.42
# 211        213           1.51651   14.38       0.00       1.94    73.61
# 212        214           1.51711   14.23       0.00       2.08    73.36
#
#      Potassium  Calcium  Barium  Iron  Type of glass
# ...

# %%
df.dtypes
# Out:
# Id number             int64
# Refractive index    float64
# Sodium              float64
# Magnisium           float64
# Aluminium           float64
# Silicon             float64
# Potassium           float64
# Calcium             float64
# Barium              float64
# Iron                float64
# Type of glass         int64
# dtype: object

# %% [markdown]
# The dataset contains two datatype float64 and int64

# %%
df.isnull().sum()
# Out:
# Id number           0
# Refractive index    0
# Sodium              0
# Magnisium           0
# Aluminium           0
# Silicon             0
# Potassium           0
# Calcium             0
# Barium              0
# Iron                0
# Type of glass       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id number         213 non-null    int64
#  1   Refractive index  213 non-null    float64
#  2   Sodium            213 non-null    float64
#  3   Magnisium         213 non-null    float64
#  4   Aluminium         213 non-null    float64
#  5   Silicon           213 non-null    float64
#  6   Potassium         213 non-null    float64
#  7   Calcium           213 non-null    float64
#  8   Barium            213 non-null    float64
#  9   Iron              213 non-null    float64
#  10  Type of glass     213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
df['Type of glass'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
df['Type of glass'].value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %%
df.drop('Id number',axis=1,inplace=True)
df
# Out:
#      Refractive index  Sodium  Magnisium  Aluminium  Silicon  Potassium  \
# 0             1.51761   13.89       3.60       1.36    72.73       0.48
# 1             1.51618   13.53       3.55       1.54    72.99       0.39
# 2             1.51766   13.21       3.69       1.29    72.61       0.57
# 3             1.51742   13.27       3.62       1.24    73.08       0.55
# 4             1.51596   12.79       3.61       1.62    72.97       0.64
# ..                ...     ...        ...        ...      ...        ...
# 208           1.51623   14.14       0.00       2.88    72.61       0.08
# 209           1.51685   14.92       0.00       1.99    73.06       0.00
# 210           1.52065   14.36       0.00       2.02    73.42       0.00
# 211           1.51651   14.38       0.00       1.94    73.61       0.00
# 212           1.51711   14.23       0.00       2.08    73.36       0.00
#
#      Calcium  Barium  Iron  Type of glass
# 0       7.83    0.00  0.00              1
# ...

# %% [markdown]
# # Summary of data

# %%
df.describe()
# Out:
#         Id number  Refractive index      Sodium   Magnisium   Aluminium  \
# count  213.000000        213.000000  213.000000  213.000000  213.000000
# mean   108.000000          1.518353   13.406761    2.676056    1.446526
# std     61.631972          0.003039    0.818371    1.440453    0.499882
# min      2.000000          1.511150   10.730000    0.000000    0.290000
# 25%     55.000000          1.516520   12.900000    2.090000    1.190000
# 50%    108.000000          1.517680   13.300000    3.480000    1.360000
# 75%    161.000000          1.519150   13.830000    3.600000    1.630000
# max    214.000000          1.533930   17.380000    3.980000    3.500000
#
#           Silicon   Potassium     Calcium      Barium        Iron  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean    72.655023    0.499108    8.957934    0.175869    0.057277
# std      0.774052    0.653035    1.426435    0.498245    0.097589
# ...

# %% [markdown]
# Mean is almost equal to median in all the columns.
# There is a large gap in between 75th percentile and maximum value in column id number and potassium mean there are outliers present
# in these columns.

# %% [markdown]
# # Data Visualisation

# %%
sns.catplot(x='Type of glass',data=df,kind='count')

# %% [markdown]
# •1- building_windows_float_processed
# •2- building_windows_non_float_processed
# •3- vehicle_windows_float_processed
# •4- vehicle_windows_non_float_processed (none in this database)
# •5- containers
# •6- tableware
# •7- headlamps
#
# building_windows_non_float_processed has the highest no. of count among all.

# %% [markdown]
# # Checking for outliers

# %%
plt.figure(figsize=(17,21), facecolor='white')
plotnumber=1
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(5,6,plotnumber)
        sns.boxplot(df[col],color='m')
        plt.xlabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# We can see presence of outliers

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#      Refractive index    Sodium  Magnisium  Aluminium   Silicon  Potassium  \
# 0            0.245101  0.591880   0.642937   0.173500  0.097091   0.029329
# 1            0.716826  0.150946   0.608144   0.187433  0.433777   0.167472
# 2            0.228607  0.240996   0.705564   0.313863  0.058303   0.108813
# 3            0.307777  0.167507   0.656854   0.414122  0.550322   0.078115
# 4            0.789399  0.755419   0.649895   0.347848  0.407878   0.216258
# ..                ...       ...        ...        ...       ...        ...
# 208          0.700332  0.898085   1.862164   2.874379  0.058303   0.643296
# 209          0.495808  1.853443   1.862164   1.089766  0.524423   0.766090
# 210          0.757727  1.167545   1.862164   1.149921  0.990604   0.766090
# 211          0.607966  1.192041   1.862164   0.989506  1.236644   0.766090
# 212          0.410039  1.008318   1.862164   1.270232  0.912907   0.766090
#
#       Calcium    Barium      Iron  Type of glass
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([104, 105, 105, 105, 105, 105, 106, 106, 106, 109, 110, 111, 111,
#         130, 144, 161, 162, 162, 162, 170, 170, 171, 171, 173, 183, 183,
#         187, 188, 200, 200, 202, 206, 212], dtype=int64),
#  array([6, 0, 1, 4, 6, 7, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 7, 3, 5, 3,
#         5, 8, 1, 4, 4, 7, 4, 5, 7, 7, 7], dtype=int64))

# %%
z.iloc[104,6]
# Out:
# 3.00900736343217

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (193, 10)

# %%
df.shape
# Out:
# (213, 10)

# %%
print('Data loss in percentage:',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss in percentage: 9.389671361502346

# %% [markdown]
# # Checking skewness

# %%
plt.figure(figsize=(35,30), facecolor='white')
plotnumber=1
for col in df1:
    if plotnumber<=10:
        ax=plt.subplot(5,6,plotnumber)
        sns.distplot(df[col], color='m')
        plt.xlabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()    
plt.show()

# %%
df1.skew()
# Out:
# Refractive index    0.971729
# Sodium              0.375857
# Magnisium          -1.533664
# Aluminium           0.649917
# Silicon            -0.436288
# Potassium           0.297900
# Calcium             1.074092
# Barium              3.178256
# Iron                1.478611
# Type of glass       1.277279
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
columns=['Refractive index','Aluminium','Calcium','Barium','Iron']

# %%
for col in columns:
    df1[col], _=boxcox(df1[col] + 1)

# %%
df1.skew()
# Out:
# Refractive index    0.000000
# Sodium              0.375857
# Magnisium          -1.533664
# Aluminium           0.014781
# Silicon            -0.436288
# Potassium           0.297900
# Calcium            -0.081151
# Barium              1.963711
# Iron                0.852040
# Type of glass       1.277279
# dtype: float64

# %% [markdown]
# # Checking correlation

# %%
df1.corr()
# Out:
#                   Refractive index    Sodium  Magnisium  Aluminium   Silicon  \
# Refractive index               NaN       NaN        NaN        NaN       NaN
# Sodium                         NaN  1.000000  -0.491934   0.193851 -0.233588
# Magnisium                      NaN -0.491934   1.000000  -0.548427 -0.371123
# Aluminium                      NaN  0.193851  -0.548427   1.000000  0.344468
# Silicon                        NaN -0.233588  -0.371123   0.344468  1.000000
# Potassium                      NaN -0.612858   0.495241   0.063956  0.062254
# Calcium                        NaN  0.013543  -0.423922  -0.261981 -0.150560
# Barium                         NaN  0.530939  -0.610778   0.555829  0.185059
# Iron                           NaN -0.155265   0.115817  -0.085704 -0.011674
# Type of glass                  NaN  0.535440  -0.809747   0.619421  0.257640
#
#                   Potassium   Calcium    Barium      Iron  Type of glass
# ...

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Type of glass is less correlated with calcium and iron.

# %% [markdown]
# # Seperating the data

# %%
x=df1.drop('Type of glass',axis=1)
y=df1['Type of glass']

# %% [markdown]
# # Scaling using standard scaler method

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Refractive index    Sodium  Magnisium  Aluminium   Silicon  Potassium  \
# 0        2.168404e-19  0.704498   0.558738  -0.077883  0.007760   0.165576
# 1        2.168404e-19  0.169658   0.520382   0.328329  0.455342  -0.154697
# 2        2.168404e-19 -0.305754   0.627781  -0.242339 -0.198816   0.485849
# 3        2.168404e-19 -0.216615   0.574081  -0.362203  0.610275   0.414677
# 4        2.168404e-19 -0.929734   0.566410   0.501750  0.420913   0.734950
# ..                ...       ...        ...        ...       ...        ...
# 188      2.168404e-19  1.417617  -2.202957   2.582027  0.214336  -1.542547
# 189      2.168404e-19  1.075914  -2.202957   2.806551 -0.198816  -1.257860
# 190      2.168404e-19  2.234732  -2.202957   1.254324  0.575845  -1.542547
# 191      2.168404e-19  1.402760  -2.202957   1.312122  1.195574  -1.542547
# 192      2.168404e-19  1.432473  -2.202957   1.156990  1.522654  -1.542547
#
#       Calcium    Barium      Iron
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
maxAccu=0
maxRS=0
for i in range(1,220):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=i)
    DTC= DecisionTreeClassifier()
    DTC.fit(x_train,y_train)
    pred=DTC.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum accuracy score is:',maxAccu, 'at random state:',maxRS)
# Out:
# Maximum accuracy score is: 0.8103448275862069 at random state: 176

# %% [markdown]
# # Again predicting decision tree classifier

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=176)

# %%
DTC= DecisionTreeClassifier()
DTC.fit(x_train,y_train)
predDTC=DTC.predict(x_test)
print('accuracy score',accuracy_score(y_test,predDTC))
print('confusion matrix',confusion_matrix(y_test,predDTC))
print('classification report',classification_report(y_test,predDTC))
# Out:
# accuracy score 0.7241379310344828
# confusion matrix [[18  3  0  0  0  0]
#  [ 4 14  1  0  1  0]
#  [ 3  0  0  0  0  0]
#  [ 0  4  0  2  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0  5]]
# classification report               precision    recall  f1-score   support
#
#            1       0.72      0.86      0.78        21
#            2       0.67      0.70      0.68        20
#            3       0.00      0.00      0.00         3
#            5       1.00      0.33      0.50         6
#            6       0.75      1.00      0.86         3
#            7       1.00      1.00      1.00         5
#
#     accuracy                           0.72        58
#    macro avg       0.69      0.65      0.64        58
# weighted avg       0.72      0.72      0.70        58

# %%
models=[KNeighborsClassifier(),
        SVC(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier(),
        RandomForestClassifier(),
        LogisticRegression(),
        DecisionTreeClassifier()]

# %%
for m in models:
    m.fit(x_train,y_train)
    pred_m=m.predict(x_test)
    print('Model prediction for :',m)
    print('accuracy score:',accuracy_score(y_test, pred_m))
    print('confusion matrix :\n',confusion_matrix(y_test, pred_m))
    print('classification report :\n',classification_report(y_test, pred_m))
    print('\n')
# Out:
# Model prediction for : KNeighborsClassifier()
# accuracy score: 0.8103448275862069
# confusion matrix :
#  [[20  1  0  0  0  0]
#  [ 3 17  0  0  0  0]
#  [ 3  0  0  0  0  0]
#  [ 0  3  0  3  0  0]
#  [ 0  0  0  0  2  1]
#  [ 0  0  0  0  0  5]]
# classification report :
#                precision    recall  f1-score   support
#
#            1       0.77      0.95      0.85        21
#            2       0.81      0.85      0.83        20
#            3       0.00      0.00      0.00         3
#            5       1.00      0.50      0.67         6
#            6       1.00      0.67      0.80         3
#            7       0.83      1.00      0.91         5
#
#     accuracy                           0.81        58
#    macro avg       0.74      0.66      0.68        58
# weighted avg       0.78      0.81      0.78        58
#
#
#
# Model prediction for : SVC()
# accuracy score: 0.7241379310344828
# confusion matrix :
#  [[16  5  0  0  0  0]
#  [ 3 17  0  0  0  0]
# ...

# %% [markdown]
# # Cross validation to check actual performance of these above models

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in models:
    score=cross_val_score(m,x,y)
    print('Cross validation score for :',m)
    print('Model score :',score)
    print('mean score :',score.mean())
    print('difference between accuracy score and Cross validation score :',accuracy_score(y_test, pred_m)-score.mean())
    print('\n')
# Out:
# Cross validation score for : KNeighborsClassifier()
# Model score : [0.66666667 0.66666667 0.69230769 0.63157895 0.68421053]
# mean score : 0.6682860998650473
# difference between accuracy score and Cross validation score : 0.14205872772115957
#
#
# Cross validation score for : SVC()
# Model score : [0.58974359 0.66666667 0.69230769 0.71052632 0.68421053]
# mean score : 0.6686909581646423
# difference between accuracy score and Cross validation score : 0.14165386942156455
#
#
# Cross validation score for : AdaBoostClassifier()
# Model score : [0.46153846 0.51282051 0.74358974 0.28947368 0.52631579]
# mean score : 0.5067476383265858
# difference between accuracy score and Cross validation score : 0.3035971892596211
#
#
# Cross validation score for : GradientBoostingClassifier()
# Model score : [0.58974359 0.69230769 0.66666667 0.60526316 0.65789474]
# mean score : 0.6423751686909581
# difference between accuracy score and Cross validation score : 0.16796965889524873
#
#
# ...

# %% [markdown]
# Among all the models RandomForestClassifier is our best model

# %% [markdown]
# # Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['gini','entropy','log_loss'],'n_estimators':[10,30,50,100],'max_depth':[10,30,50,80],'max_features':['auto','sqrt'],'n_jobs':[-2,-1,1]}
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 50,
#  'max_features': 'sqrt',
#  'n_estimators': 100,
#  'n_jobs': 1}

# %% [markdown]
# # Final Model

# %%
final=RandomForestClassifier(criterion='gini',max_depth=50,max_features='sqrt',n_estimators=100,n_jobs=1)
final.fit(x_train,y_train)
pred_f=final.predict(x_test)
accu=accuracy_score(y_test,pred_f)
print(accu*100)
# Out:
# 81.03448275862068

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(final,'Glass_Identification.pkl')
# Out:
# ['Glass_Identification.pkl']

# %% [markdown]
# # Final Prediction

# %%
prediction=final.predict(x_test)
original=np.array(y_test)
df_final=pd.DataFrame()
df_final['Predicted']= prediction
df_final['Original value']= original
df_final
# Out:
#     Predicted  Original value
# 0           1               1
# 1           2               2
# 2           5               5
# 3           2               2
# 4           2               2
# 5           2               2
# 6           1               1
# 7           1               1
# 8           1               1
# 9           1               3
# 10          1               1
# 11          1               3
# 12          1               1
# 13          1               3
# 14          1               1
# 15          1               1
# 16          2               2
# 17          2               2
# 18          2               2
# 19          2               2
# 20          1               1
# 21          1               1
# 22          1               1
# 23          1               1
# 24          2               2
# 25          2               1
# 26          5               5
# 27          2               1
# 28          2               5
# 29          6               6
# ...
